# %%
import pandas as pd

# %%
#Importando el df desde el archivo csv alojado en github.
url = 'https://raw.githubusercontent.com/ignaciomz/CoderHouse_IM/main/WineQT.csv'
qw = pd.read_csv(url, sep=';')
qw
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
#La info del df.
qw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   object
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   object
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 116.2+ KB

# %%
#Describe el df. Hace un conteo, una media, el standar, el minimo, el cuarto, la mitad, los 3 cuartos, y el maximo.
qw.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide           pH  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     3.311015
# std       0.047267            10.250486             32.782130     0.156664
# ...

# %%
#Obteniendo los valores de la fila '1138'.
qw.loc[1138]
# Out:
# fixed acidity               6.3
# volatile acidity           0.51
# citric acid                0.13
# residual sugar              2.3
# chlorides                 0.076
# free sulfur dioxide        29.0
# total sulfur dioxide       40.0
# density                 0.99574
# pH                         3.42
# sulphates                  0.75
# alcohol                    11.0
# quality                       6
# Id                         1592
# Name: 1138, dtype: object

# %%
#Obteniedno los valores de la fila '38'.
qw.iloc[38]
# Out:
# fixed acidity              7.6
# volatile acidity          0.51
# citric acid               0.15
# residual sugar             2.8
# chlorides                 0.11
# free sulfur dioxide       33.0
# total sulfur dioxide      73.0
# density                 0.9955
# pH                        3.17
# sulphates                 0.63
# alcohol                   10.2
# quality                      6
# Id                          54
# Name: 38, dtype: object

# %%
qw.index
# Out:
# RangeIndex(start=0, stop=1143, step=1)

# %%
#Obteniendo las columnas del df.
qw.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %%
#Obteniendo los valores del df.
qw.values
# Out:
# array([[7.4, 0.7, 0.0, ..., '9.4', 5, 0],
#        [7.8, 0.88, 0.0, ..., '9.8', 5, 1],
#        [7.8, 0.76, 0.04, ..., '9.8', 5, 2],
#        ...,
#        [6.2, 0.6, 0.08, ..., '10.5', 5, 1594],
#        [5.9, 0.55, 0.1, ..., '11.2', 6, 1595],
#        [5.9, 0.645, 0.12, ..., '10.2', 5, 1597]], dtype=object)

# %%
#Obteniendo la forma del df.
qw.shape
# Out:
# (1143, 13)

# %%
#Valores de la columna 'density'.
qw.density
# Out:
# 0                   0.9978
# 1                   0.9968
# 2                    0.997
# 3                    0.998
# 4                   0.9978
#                ...
# 1138               0.99574
# 1139               0.99651
# 1140                0.9949
# 1141    0.9951200000000001
# 1142    0.9954700000000001
# Name: density, Length: 1143, dtype: object

# %%
#Obteniedno valores de la fila 0 a la 4.
qw.values[0:4]
# Out:
# array([[7.4, 0.7, 0.0, 1.9, 0.076, 11.0, 34.0, '0.9978', 3.51, 0.56,
#         '9.4', 5, 0],
#        [7.8, 0.88, 0.0, 2.6, 0.098, 25.0, 67.0, '0.9968', 3.2, 0.68,
#         '9.8', 5, 1],
#        [7.8, 0.76, 0.04, 2.3, 0.092, 15.0, 54.0, '0.997', 3.26, 0.65,
#         '9.8', 5, 2],
#        [11.2, 0.28, 0.56, 1.9, 0.075, 17.0, 60.0, '0.998', 3.16, 0.58,
#         '9.8', 6, 3]], dtype=object)

# %%
#Obteniedno los valores de las columnas ['Id', 'density', 'quality', 'alcohol'], donde los valores de la columna 'Density' sean mayores o iguales a 0.99.
qw.loc[qw.density >= 0.99, ['Id', 'density', 'quality', 'alcohol']]
# Out:
#         Id  density  quality alcohol
# 0        0  0.99780        5     9.4
# 1        1  0.99680        5     9.8
# 2        2  0.99700        5     9.8
# 3        3  0.99800        6     9.8
# 4        4  0.99780        5     9.4
# ...    ...      ...      ...     ...
# 1138  1592  0.99574        6    11.0
# 1139  1593  0.99651        6     9.5
# 1140  1594  0.99490        5    10.5
# 1141  1595  0.99512        6    11.2
# 1142  1597  0.99547        5    10.2
#
# [1142 rows x 4 columns]

# %%
#Probando transponer.
qw.T
# Out:
#                         0       1      2      3       4       5       6     \
# fixed acidity            7.4     7.8    7.8   11.2     7.4     7.4     7.9
# volatile acidity         0.7    0.88   0.76   0.28     0.7    0.66     0.6
# citric acid              0.0     0.0   0.04   0.56     0.0     0.0    0.06
# residual sugar           1.9     2.6    2.3    1.9     1.9     1.8     1.6
# chlorides              0.076   0.098  0.092  0.075   0.076   0.075   0.069
# free sulfur dioxide     11.0    25.0   15.0   17.0    11.0    13.0    15.0
# total sulfur dioxide    34.0    67.0   54.0   60.0    34.0    40.0    59.0
# density               0.9978  0.9968  0.997  0.998  0.9978  0.9978  0.9964
# pH                      3.51     3.2   3.26   3.16    3.51    3.51     3.3
# sulphates               0.56    0.68   0.65   0.58    0.56    0.56    0.46
# alcohol                  9.4     9.8    9.8    9.8     9.4     9.4     9.4
# ...

# %%
#Transponiendo el df qw y alojandolo en una nueva variable 'qw2'.
qw2 = qw.T
qw2
# Out:
#                         0       1      2      3       4       5       6     \
# fixed acidity            7.4     7.8    7.8   11.2     7.4     7.4     7.9
# volatile acidity         0.7    0.88   0.76   0.28     0.7    0.66     0.6
# citric acid              0.0     0.0   0.04   0.56     0.0     0.0    0.06
# residual sugar           1.9     2.6    2.3    1.9     1.9     1.8     1.6
# chlorides              0.076   0.098  0.092  0.075   0.076   0.075   0.069
# free sulfur dioxide     11.0    25.0   15.0   17.0    11.0    13.0    15.0
# total sulfur dioxide    34.0    67.0   54.0   60.0    34.0    40.0    59.0
# density               0.9978  0.9968  0.997  0.998  0.9978  0.9978  0.9964
# pH                      3.51     3.2   3.26   3.16    3.51    3.51     3.3
# sulphates               0.56    0.68   0.65   0.58    0.56    0.56    0.46
# alcohol                  9.4     9.8    9.8    9.8     9.4     9.4     9.4
# ...

# %%
#Error al intentar buscar mal los valores de las columnas ['density', 'quality', 'alcohol'] del valor 1138 de la columna 'Id'.
qw.loc[qw.id == 1138, ['density', 'quality', 'alcohol']]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-114-d08201766142> in <cell line: 1>()
# ----> 1 qw.loc[qw.id == 1138, ['density', 'quality', 'alcohol']]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'id'

# %%
#Buscando los valores de las columnas ['Id','density', 'quality', 'alcohol'] para los valores [3, 5, 11, 27] de la columna 'Id'.
qw.loc[qw['Id'].isin([3, 5, 11, 27]), ['Id','density', 'quality', 'alcohol']]
# Out:
#    Id  density  quality alcohol
# 3   3   0.9980        6     9.8
# 5   5   0.9978        5     9.4

# %%
#Buscando nulls / -Nan-.
qw.isnull().head(20)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           False             False        False           False      False
# 1           False             False        False           False      False
# 2           False             False        False           False      False
# 3           False             False        False           False      False
# 4           False             False        False           False      False
# 5           False             False        False           False      False
# 6           False             False        False           False      False
# 7           False             False        False           False      False
# 8           False             False        False           False      False
# 9           False             False        False           False      False
# 10          False             False        False           False      False
# ...

# %%
import numpy as np

# %%
#Forma del df.
qw.shape
# Out:
# (1143, 13)

# %%
#Tamaño del df.
qw.size
# Out:
# 14859

# %%
#Cantidad de dimensiones.
qw.ndim
# Out:
# 2

# %%
#Información de la columna 'alcohol'.
qw['alcohol'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1143 entries, 0 to 1142
# Series name: alcohol
# Non-Null Count  Dtype
# --------------  -----
# 1143 non-null   object
# dtypes: object(1)
# memory usage: 9.1+ KB

# %%
#Obtengo la cantidad de memoria que usa cada columna, en bytes.
qw.memory_usage()
# Out:
# Index                    128
# fixed acidity           9144
# volatile acidity        9144
# citric acid             9144
# residual sugar          9144
# chlorides               9144
# free sulfur dioxide     9144
# total sulfur dioxide    9144
# density                 9144
# pH                      9144
# sulphates               9144
# alcohol                 9144
# quality                 9144
# Id                      9144
# dtype: int64

# %%
#Para obtener las dos primeras filas y dos primeras columnas.
qw.iloc[:2, :2]
# Out:
#    fixed acidity  volatile acidity
# 0            7.4              0.70
# 1            7.8              0.88
